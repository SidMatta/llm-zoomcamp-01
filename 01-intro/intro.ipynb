# %%
import openai

# %%
from openai import OpenAI

# %%
import os
#os.environ.get("OPENAI_API_KEY")

# %%
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])

# %%
# response = client.responses.create

# %%
response = client.responses.create(
    model="gpt-4.1-mini",
    input="What is the latest on Cricket T20 World Cup?"
)

print(response.output_text)
# Out:
# As of June 2024, the latest updates on the ICC Men's T20 World Cup are:
#
# - The next ICC Men's T20 World Cup is scheduled to be held in 2024.
# - It will take place in the West Indies and the United States, marking the first time parts of the tournament will be hosted in the USA.
# - The tournament is planned for June to July 2024.
# - The event will feature 20 teams, expanded from previous editions.
#
# If you want information on ongoing matches, fixtures, or team news, please specify!

# %%
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[{"role":"user","content":"is it too late to join the course?"}]
)

# %%
response.choices[0].message.content
# Out:
# "I'm sorry, but I don’t have specific details about the course you're referring to. To get an accurate answer, you'll need to check the enrollment deadlines and requirements for the specific course you're interested in. This information is typically available on the course provider’s website or by directly contacting them."

# %%
response
# Out:
# ChatCompletion(id='chatcmpl-D6rwYRrH4Ysd2Zha9kWEzfbCReHWs', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="I'm sorry, but I don’t have specific details about the course you're referring to. To get an accurate answer, you'll need to check the enrollment deadlines and requirements for the specific course you're interested in. This information is typically available on the course provider’s website or by directly contacting them.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1770529698, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_ad98c18a04', usage=CompletionUsage(completion_tokens=57, prompt_tokens=16, total_tokens=73, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
