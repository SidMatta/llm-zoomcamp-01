# %%
# !wget https://raw.githubusercontent.com/SidMatta/search-eng-101/refs/heads/main/search-eng.ipynb
# Out:
# --2026-01-27 04:42:21--  https://raw.githubusercontent.com/SidMatta/search-eng-101/refs/heads/main/search-eng.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 829135 (810K) [text/plain]
# Saving to: ‘search-eng.ipynb’
#
# search-eng.ipynb    100%[===================>] 809.70K  --.-KB/s    in 0.009s
#
# 2026-01-27 04:42:21 (84.1 MB/s) - ‘search-eng.ipynb’ saved [829135/829135]

# %%
import minsearch

# %%
import json
